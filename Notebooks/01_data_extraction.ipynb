# %% [markdown]
# # ITSM Machine Learning Project
#
# ## Business Objective
#
# The objective of this project is to improve IT Service Management (ITSM) operations using Machine Learning techniques.
#
# The project focuses on:
#
# 1. Predicting high-priority incidents
# 2. Forecasting incident volumes
# 3. Auto-tagging departments and priorities
# 4. Predicting RFC failures

# %% [markdown]
# DATASET DESCRIPTION

# %% [markdown]
# ## Dataset Description
#
# The dataset contains ITSM incident management records collected between 2012 and 2014.
#
# Total Records: ~46,000
#
# The dataset includes:
# - Incident details
# - Priority levels
# - Impact and urgency
# - Reassignment counts
# - Time-based incident information
# - Closure information

# %% [markdown]
# IMPORT LIBRAIRES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import mysql.connector
import os

# %% [markdown]
# CONNECT TO DATA BASE

# %%
DB_PASSWORD = "DM!$Team@&27920!"

conn = mysql.connector.connect(
    host="18.136.157.135",
    user="dm_team",
    password=DB_PASSWORD,
    database="project_itsm"
)

print("Database Connected Successfully")
# Out:
# Database Connected Successfully

# %% [markdown]
# CURSOR

# %%
cursor = conn.cursor()

cursor.execute("SHOW TABLES")

for table in cursor:
    print(table)
# Out:
# ('dataset_list',)

# %% [markdown]
# LOAD DATASET

# %%
df = pd.read_sql("SELECT * FROM dataset_list", conn)
# Out:
# C:\Users\nutha\AppData\Local\Temp\ipykernel_18696\1981340733.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM dataset_list", conn)

# %%
df.shape
# Out:
# (46606, 25)

# %%
df.head(10)
# Out:
#      CI_Name          CI_Cat              CI_Subcat        WBS Incident_ID  \
# 0  SUB000508  subapplication  Web Based Application  WBS000162   IM0000004
# 1  WBA000124     application  Web Based Application  WBS000088   IM0000005
# 2  DTA000024     application    Desktop Application  WBS000092   IM0000006
# 3  WBA000124     application  Web Based Application  WBS000088   IM0000011
# 4  WBA000124     application  Web Based Application  WBS000088   IM0000012
# 5  WBA000124     application  Web Based Application  WBS000088   IM0000013
# 6  WBA000082     application  Web Based Application  WBS000055   IM0000014
# 7  WBA000124     application  Web Based Application  WBS000088   IM0000015
# 8  WBA000124     application  Web Based Application  WBS000088   IM0000017
# 9  WBA000082     application  Web Based Application  WBS000055   IM0000018
#
#    Status Impact Urgency Priority   number_cnt  ...       Reopen_Time  \
# 0  Closed      4       4        4  0.601292279  ...
# ...

# %%
df.columns
# Out:
# Index(['CI_Name', 'CI_Cat', 'CI_Subcat', 'WBS', 'Incident_ID', 'Status',
#        'Impact', 'Urgency', 'Priority', 'number_cnt', 'Category', 'KB_number',
#        'Alert_Status', 'No_of_Reassignments', 'Open_Time', 'Reopen_Time',
#        'Resolved_Time', 'Close_Time', 'Handle_Time_hrs', 'Closure_Code',
#        'No_of_Related_Interactions', 'Related_Interaction',
#        'No_of_Related_Incidents', 'No_of_Related_Changes', 'Related_Change'],
#       dtype='str')

# %% [markdown]
# ## Important Features for Machine Learning
#
# The following features are useful for solving business problems:
#
# - Impact
# - Urgency
# - Category
# - Closure_Code
# - No_of_Reassignments
# - Open_Time
# - CI_Category
# - CI_Subcategory
#
# These features will support classification and forecasting tasks.

# %% [markdown]
# TARGET VARIABLE EXPLANATION

# %% [markdown]
# ## Target Variables
#
# Machine Learning targets used in this project:
#
# 1. Priority → Priority Prediction
# 2. Incident Volume → Forecasting
# 3. Category / CI fields → Auto-tagging
# 4. Failure indicators → RFC Failure Prediction

# %% [markdown]
# SAVE RAW CSV

# %%
os.makedirs("../data/raw", exist_ok=True)

df.to_csv("../data/raw/itsm_raw.csv", index=False)

print("Raw CSV Saved Successfully")
# Out:
# Raw CSV Saved Successfully

# %% [markdown]
# ## Export Raw Dataset
#
# The extracted dataset is stored locally for preprocessing and machine learning workflows.

# %%
os.listdir("../data/raw")
# Out:
# ['itsm_raw.csv']
